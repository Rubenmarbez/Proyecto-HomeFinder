# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 

from Funciones_Datos_EDA import *

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('proyecto_viviendas.csv')
df.head()
# Out:
#    Unnamed: 0                                            Títulos  \
# 0           0  Piso en venta en Pacífico de 5 habitaciones co...
# 1           1  Piso en venta en Justicia - Chueca de 1 habita...
# 2           2  Venta de piso en Embajadores - Lavapiés de 1 h...
# 3           3  Venta de piso en Canillas de 4 habitaciones co...
# 4           4  Venta de piso en Piovera - Conde Orgaz de 4 ha...
#
#                                 Ubicaciones      Precios  \
# 0                  Pacífico, Retiro, Madrid    565.000 €
# 1         Justicia - Chueca, Centro, Madrid    299.990 €
# 2    Embajadores - Lavapiés, Centro, Madrid    179.000 €
# 3               Canillas, Hortaleza, Madrid  1.875.000 €
# 4  Piovera - Conde Orgaz, Hortaleza, Madrid  1.795.000 €
#
#    Número de habitaciones  Número de baños Medidas  \
# 0                     5.0              2.0  160 m²
# 1                     1.0              1.0   84 m²
# 2                     1.0              1.0   57 m²
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9996 entries, 0 to 9995
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              9996 non-null   int64
#  1   Títulos                 9972 non-null   object
#  2   Ubicaciones             9972 non-null   object
#  3   Precios                 9972 non-null   object
#  4   Número de habitaciones  9798 non-null   float64
#  5   Número de baños         9972 non-null   float64
#  6   Medidas                 9972 non-null   object
#  7   Equipamientos           9957 non-null   object
#  8   Características         9972 non-null   object
#  9   Consumo energético      5615 non-null   object
#  10  Descripciones           9971 non-null   object
#  11  Fechas de publicación   9972 non-null   object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 937.3+ KB

# %%
df = total_eda(df)
# Out:
# c:\Users\ruben\OneDrive\Documentos\Bootcamp\Apuntes Bootcamp\Librerías\Proyecto Final\Proyecto\Funciones_Datos_EDA.py:17: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   viviendas['Equipamientos'] = viviendas['Equipamientos'].str.replace('[', '').str.replace(']', '')
# c:\Users\ruben\OneDrive\Documentos\Bootcamp\Apuntes Bootcamp\Librerías\Proyecto Final\Proyecto\Funciones_Datos_EDA.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   viviendas['Características'] = viviendas['Características'].str.replace('[', '').str.replace(']', '')
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7465 entries, 0 to 7464
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Distrito                 7456 non-null   object
#  1   Barrio                   7453 non-null   object
#  2   Precio                   7465 non-null   Int64
#  3   Habitaciones             7332 non-null   Int64
#  4   Baños                    7465 non-null   Int64
#  5   Superficie               7465 non-null   Int64
#  6   Aire acondicionado       7465 non-null   bool
#  7   Amueblado                7465 non-null   bool
#  8   Armarios empotrados      7465 non-null   bool
#  9   Ascensor                 7465 non-null   bool
#  10  Balcón                   7465 non-null   bool
#  11  Calefacción              7465 non-null   bool
#  12  Garaje                   7465 non-null   bool
#  13  Jardín                   7465 non-null   bool
# ...

# %%
df.isnull().sum()
# Out:
# Distrito                      9
# Barrio                       12
# Precio                        0
# Habitaciones                133
# Baños                         0
# Superficie                    0
# Aire acondicionado            0
# Amueblado                     0
# Armarios empotrados           0
# Ascensor                      0
# Balcón                        0
# Calefacción                   0
# Garaje                        0
# Jardín                        0
# Piscina                       0
# Terraza                       0
# Año de construcción        2265
# Planta                     1034
# Estado                        0
# Interior/Exterior           835
# Tipo de calefacción        3220
# Sistema de calefacción     1063
# Calificación energética    3302
# dtype: int64

# %%
df.head()
# Out:
#     Distrito                  Barrio   Precio  Habitaciones  Baños  \
# 0     Retiro                Pacífico   565000             5      2
# 1     Centro       Justicia - Chueca   299990             1      1
# 2     Centro  Embajadores - Lavapiés   179000             1      1
# 3  Hortaleza                Canillas  1875000             4      5
# 4  Hortaleza   Piovera - Conde Orgaz  1795000             4      5
#
#    Superficie  Aire acondicionado  Amueblado  Armarios empotrados  Ascensor  \
# 0         160               False      False                 True      True
# 1          84               False      False                False     False
# 2          57               False      False                False     False
# 3         346                True      False                 True      True
# 4         291                True       True                 True      True
#
#    Balcón  Calefacción  Garaje  Jardín  Piscina  Terraza  Año de construcción  \
# ...

# %%
# df.to_pickle('viviendas_eda2.pkl')
# df.to_csv('viviendas_eda2.csv', index=True)
